# %% [markdown]
# ## Create a Haystack RAG pipeline using Amazon Bedrock - Part 1
# ---
#
# Haystack is an open-source framework by deepset that allows developers to orchestrate LLM applications made up of different components like models, vector DBs, file converters, and countless other modules. Haystack provides pipelines and Agents, two powerful structures for designing LLM applications for various use cases including search, question answering, and conversational AI. With a big focus on state-of-the art retrieval methods and solid evaluation metrics, it provides you with everything you need to ship a reliable, trustworthy application. You can serialize pipelines to YAML files, expose them via a REST API, and scale them flexibly with your workloads, making it easy to move your application from a prototype stage to production.
#
# In this notebook series, we will use Amazon Bedrock as a `DocumentTextEmbedder`, `TextEmbedder` and `Generator`. We will use the `amazon.titan-embed-text-v2:0` as our choice of embeddings model and `anthropic.claude-3-5-sonnet-20240620-v1:0` as our choice of generator model.
#
# In this notebook, we will do as follows:
#
# 1. Create a standard RAG pipeline on Haystack. We will use the `vblagoje/PubMedQA_instruction` dataset from where we will load documents in the InMemoryDataStore.
#
# 1. Embed the document and connect it to a writer, and write `1000` rows of this dataset to the `InMemoryDocumentStore` using `cosine` as the `embedding_similarity_function`
#
# 1. Create a RAG Anthropic Claude prompt template and use it in the prompt builder. We will also create an `AmazonBedrockGenerator` and use a `InMemoryBM25Retriever` as the retriever.
#
# 1. Lastly, we will connect all of these components into a single pipeline, serialize the pipeline and save it.
#
# Once the pipeline is saved, we can load it in the next notebook and run inferences, and evaluate some of the responses.

# %%
# For each component, it is essential to know the names of the input and the output. There are several components for various steps
# of the generative AI pipeline that are provided out of the box. This includes components for document stores, embedders, prompt
# builders and generators. You can also build your own component.
# !pip install -Uq pip
# !pip install -Uq haystack
# !pip install -Uq sentence-transformers
# !pip install -Uq amazon-bedrock-haystack

# %%
# Install the Chroma integration, Haystack will come as a dependency
# !pip install -U chroma-haystack "huggingface_hub>=0.22.0"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: chroma-haystack in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: huggingface_hub>=0.22.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (0.26.2)
# Requirement already satisfied: chromadb>=0.5.17 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chroma-haystack) (0.5.18)
# Requirement already satisfied: haystack-ai in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chroma-haystack) (2.7.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chroma-haystack) (4.9.0)
# Requirement already satisfied: filelock in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (6.0.2)
# Requirement already satisfied: requests in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from huggingface_hub>=0.22.0) (4.66.1)
# Requirement already satisfied: build>=1.0.3 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.0.3)
# Requirement already satisfied: pydantic>=1.9 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.95.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (0.22.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.26.3)
# Requirement already satisfied: posthog>=2.4.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (3.5.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.17.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (1.62.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (4.1.2)
# Requirement already satisfied: typer>=0.9.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (8.2.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (3.10.0)
# Requirement already satisfied: httpx>=0.27.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from chromadb>=0.5.17->chroma-haystack) (13.7.1)
# Requirement already satisfied: haystack-experimental in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (0.3.0)
# Requirement already satisfied: jinja2 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (3.1.3)
# Requirement already satisfied: lazy-imports in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (0.3.1)
# Requirement already satisfied: more-itertools in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (10.2.0)
# Requirement already satisfied: networkx in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (3.3)
# Requirement already satisfied: openai>=1.1.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (1.14.3)
# Requirement already satisfied: pandas in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (2.1.4)
# Requirement already satisfied: python-dateutil in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from haystack-ai->chroma-haystack) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.22.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.22.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.22.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from requests->huggingface_hub>=0.22.0) (2024.2.2)
# Requirement already satisfied: pyproject_hooks in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.5.17->chroma-haystack) (1.0.0)
# Collecting pydantic>=1.9 (from chromadb>=0.5.17->chroma-haystack)
#   Downloading pydantic-1.10.19-cp311-cp311-macosx_11_0_arm64.whl.metadata (152 kB)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb>=0.5.17->chroma-haystack) (0.27.0)
# Requirement already satisfied: anyio in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.5.17->chroma-haystack) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.5.17->chroma-haystack) (1.0.5)
# Requirement already satisfied: sniffio in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.5.17->chroma-haystack) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.5.17->chroma-haystack) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (3.2.2)
# Requirement already satisfied: coloredlogs in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (24.3.25)
# Requirement already satisfied: protobuf in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (4.25.2)
# Requirement already satisfied: sympy in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (1.12)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from openai>=1.1.0->haystack-ai->chroma-haystack) (1.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.5.17->chroma-haystack) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.5.17->chroma-haystack) (6.11.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->chroma-haystack) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->chroma-haystack) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->chroma-haystack) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (69.0.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.17->chroma-haystack) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.17->chroma-haystack) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.5.17->chroma-haystack) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.5.17->chroma-haystack) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.5.17->chroma-haystack) (2.17.2)
# Requirement already satisfied: click>=8.0.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.5.17->chroma-haystack) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.5.17->chroma-haystack) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (1.0.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->chroma-haystack) (12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from jinja2->haystack-ai->chroma-haystack) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from pandas->haystack-ai->chroma-haystack) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from pandas->haystack-ai->chroma-haystack) (2023.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (4.7.2)
# Requirement already satisfied: zipp>=0.5 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.5.17->chroma-haystack) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.17->chroma-haystack) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.17->chroma-haystack) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/madhurpt/Library/Application Support/pypoetry/venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->chroma-haystack) (0.6.1)
# Downloading pydantic-1.10.19-cp311-cp311-macosx_11_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.7 MB/s eta 0:00:00
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dspy 2.5.30 requires pydantic~=2.0, but you have pydantic 1.10.19 which is incompatible.
# Successfully installed pydantic-1.10.19

# %%
# Install all of the latest packages within DSPy using the following command
# !pip install -Uq git+https://github.com/stanfordnlp/dspy.git
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastapi 0.95.2 requires pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2, but you have pydantic 2.9.2 which is incompatible.

# %%
# import libraries
import os
# import dspy
import json
import boto3
import pickle
import logging
import tempfile
import globals as g
import pandas as pd
from globals import *
from haystack import Pipeline
from datasets import load_dataset
from haystack.dataclasses import Document
# from dspy.primitives.prediction import Prediction
from haystack.components.writers import DocumentWriter
from haystack.components.builders import PromptBuilder
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.retrievers.in_memory import InMemoryBM25Retriever
from haystack_integrations.document_stores.chroma import ChromaDocumentStore
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack_integrations.components.embedders.amazon_bedrock import (
    AmazonBedrockDocumentEmbedder,
    AmazonBedrockTextEmbedder,
)
from haystack_integrations.components.generators.amazon_bedrock import AmazonBedrockGenerator

# %%
# Set a logger
logging.basicConfig(format='[%(asctime)s] p%(process)s {%(filename)s:%(lineno)d} %(levelname)s - %(message)s', level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
# initialize a haystack pipeline
pipeline = Pipeline()

# At this point, all we have done is initialized the pipeline. As we try to view some of the contents
# of the pipeline, we will see that the pipeline is empty. This is because we have not yet added any
# components to the pipeline. We will now add some components to the pipeline.
pipeline.show()

# %%
# This dataset contains information about instructions, context for that instruction, a response and the category, 
dataset = load_dataset("vblagoje/PubMedQA_instruction")

# Shuffle and select 1000 samples from the 'train' split
train_data = dataset['train'].shuffle(seed=42).select(range(NUM_ROWS))
df = pd.DataFrame(train_data)

# Save as CSV
os.makedirs(g.DATA_DIR, exist_ok=True)
csv_path = os.path.join(g.DATA_DIR, g.PUBMED_QA_CSV_FNAME)
df.to_csv(csv_path, index=False)
logger.info(f"Dataset saved to {csv_path}")
df.head()
# Out:
# [2024-11-16 13:08:48,815] p36636 {877774040.py:12} INFO - Dataset saved to data/PubMedQA_instruction.csv
#                                          instruction  \
# 0  Do cC and CXC chemokine levels in children wit...
# 1  Are sAH gene variants associated with obesity-...
# 2  Do the functional anatomy of gaze-evoked tinni...
# 3  Does neighborhood fast-food outlet exposure am...
# 4  Does conditioned pain modulation predict exerc...
#
#                                              context  \
# 0  Chemokines are a superfamily of small peptides...
# 1  The SAH gene locus has recently been proposed ...
# 2  To identify neural sites associated with gaze-...
# 3  Greater exposures to fast-food outlets and low...
# 4  Conditioned pain modulation (CPM) is the conce...
#
#                                             response   category
# 0  Initial-phase serum levels of chemokines in pa...  closed_qa
# 1  We confirm recent evidence that the SAH locus ...  closed_qa
# 2  Patients with GET have plastic changes in mult...  closed_qa
# 3  These findings suggest that efforts to improve...  closed_qa
# 4  CPM was attenuated in older adults, as measure...  closed_qa

# %%
# view the information on the dataset that is loaded
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  1000 non-null   object
#  1   context      1000 non-null   object
#  2   response     1000 non-null   object
#  3   category     1000 non-null   object
# dtypes: object(4)
# memory usage: 31.4+ KB

# %% [markdown]
# #### Load the `vblagoje/PubMedQA_instruction` dataset in the in-memory document store
#
# Now, we will load the document to the in `InMemoryDocumentStore` using the `cosine` similarity function. We will use the `AmazonBedrockDocumentEmbedder` to embed the documents and then connect the embedder to the writer.

# %%
# Create an InMemoryDocumentStore with cosine similarity
# Run the pipeline with the documents from the DataFrame
chroma_persist_path = os.path.join(g.DATA_DIR, "chroma_store")
os.makedirs(chroma_persist_path, exist_ok=True)
document_store = ChromaDocumentStore(
    persist_path=chroma_persist_path,
    collection_name="documents",
    distance_function="cosine"
)

# Initialize the Bedrock document embedder with Titan model
document_embedder = AmazonBedrockDocumentEmbedder(
    model=g.TITAN_TEXT_EMBED_MODELID,
    aws_region=g.AWS_REGION # Specify your AWS region
)

# Add components to the pipeline
pipeline.add_component('embedder', document_embedder)
pipeline.add_component('writer', DocumentWriter(document_store))

# Connect the components
# The embedder will create embeddings that the writer will store
pipeline.connect('embedder.documents', 'writer.documents')
# Out:
# [2024-11-16 13:08:48,843] p36636 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# <haystack.core.pipeline.pipeline.Pipeline object at 0x32105b190>
# 🚅 Components
#   - embedder: AmazonBedrockDocumentEmbedder
#   - writer: DocumentWriter
# 🛤️ Connections
#   - embedder.documents -> writer.documents (List[Document])

# %% [markdown]
# #### View the current status of the pipeline. At this point, we will see an embedder and a writer. The embedder takes in a list of documents as input, embeds them and the writer uses the DocumentWriter to write those documents

# %%
pipeline.show()

# %% [markdown]
# ### Write the documents to the document store using `pipeline.run` on the `embedder`
#
# Now, we will write the documents using the embedder.

# %%
# Load the dataset
df = pd.read_csv(csv_path) 

# Prepare documents
documents = []
for _, row in df.iterrows():
    doc = Document(
        content=f"Instruction: {row['instruction']}\nContext: {row['context']}\nResponse: {row['response']}",
        meta={
            "category": row["category"],
            "question": row["instruction"]
        }
    )
    documents.append(doc)

# Run the pipeline with documents
pipeline.run({
    "embedder": {
        "documents": documents
    }
})
# Out:
# [2024-11-16 13:08:49,089] p36636 {pipeline.py:75} INFO - Running component embedder
# Creating embeddings: 100%|██████████| 1000/1000 [01:58<00:00,  8.41it/s]
# [2024-11-16 13:10:48,158] p36636 {pipeline.py:75} INFO - Running component writer
# [2024-11-16 13:10:48,160] p36636 {posthog.py:22} INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2024-11-16 13:10:48,260] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: b0ed113f8aeaf4a32eb471ce17662234549b3878a4d46a09a95707eb08a00948
# [2024-11-16 13:10:48,261] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: b0ed113f8aeaf4a32eb471ce17662234549b3878a4d46a09a95707eb08a00948
# [2024-11-16 13:10:48,264] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: bcc4a7a5fd909de875f401e32b6a6c218fecad204d366f1eae11f28eb50bad5b
# [2024-11-16 13:10:48,264] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: bcc4a7a5fd909de875f401e32b6a6c218fecad204d366f1eae11f28eb50bad5b
# [2024-11-16 13:10:48,266] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: e9026e45692aab9642a93373dc020e90b7926a91eec705c614440d552ea3a335
# [2024-11-16 13:10:48,267] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: e9026e45692aab9642a93373dc020e90b7926a91eec705c614440d552ea3a335
# [2024-11-16 13:10:48,270] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: 02a52f285c9ad28d1e69348b6ff8ee531ce56fb895193748cb69ed920a7cea04
# [2024-11-16 13:10:48,270] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: 02a52f285c9ad28d1e69348b6ff8ee531ce56fb895193748cb69ed920a7cea04
# [2024-11-16 13:10:48,273] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: 7f87f8e5c1b4221a1b3283e98eb4436433652ba023fafe416b91d87448a3ae63
# [2024-11-16 13:10:48,273] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID:
p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: da52c4419d061d9411d4313bccb7be45f21359ae2336a4ec63e31a90391f536a
# [2024-11-16 13:10:52,797] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: df83c093f8fc6fe0e9c0d51dfa9fe79b8f7c3e77e2702adfe320fa8f04a6caeb
# [2024-11-16 13:10:52,797] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: df83c093f8fc6fe0e9c0d51dfa9fe79b8f7c3e77e2702adfe320fa8f04a6caeb
# [2024-11-16 13:10:52,799] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: 22a24ad0628fbe8dd940985e08fc89dae5e2ed68bed39623d4ede513e17b234d
# [2024-11-16 13:10:52,799] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: 22a24ad0628fbe8dd940985e08fc89dae5e2ed68bed39623d4ede513e17b234d
# [2024-11-16 13:10:52,802] p36636 {sqlite.py:297} WARNING - Insert of existing embedding ID: 1fac42bec607527dc98f4b8e244449049d2f98ef4ea07875981f71b81373a812
# [2024-11-16 13:10:52,802] p36636 {local_persistent_hnsw.py:339} WARNING - Add of existing embedding ID: 1fac42bec607527dc98f4b8e244449049d2f98ef4ea07875981f71b81373a812
# {'writer': {'documents_written': 1000}}

# %%
print(f"Added {len(documents)} documents to the document store.")
# Out:
# Added 1000 documents to the document store.

# %% [markdown]
# ### Create the haystack pipeline
# ---
#
# ### RAG Pipeline Implementation with Haystack and Amazon Bedrock
#
# 1. Generator Initialization: Initialize Amazon Bedrock generator for response generation
# - Uses specified Bedrock model ID
# - Handles the inference/completion step in the RAG pipeline
#
# 2. Retriever Setup: Initialize ChromaQueryTextRetriever retriever with in-memory document store
# - Uses BM25 algorithm for document similarity scoring
# - top_k=3 retrieves the 3 most relevant documents
#
# 3. Define Jinja2 template for structuring the prompt
#
# ```
# <result>
# {% for document in documents %}
#     {{ document.content }}
# {% endfor %}
#
# To answer the question "{{question}}":
# [Provide a concise answer to the question based on the given context. Include relevant details and figures as needed, but avoid unnecessary elaboration or tangents.]
# </result>
# ```
#
# At the end, we connect the components together and create a fully functioning haystack pipeline using Amazon Bedrock.

# %%
from haystack_integrations.components.retrievers.chroma import ChromaQueryTextRetriever

# Initialize the amazon bedrock generator that is used to generate responses to questions
# at the inference step of the RAG pipeline
generator = AmazonBedrockGenerator(model=g.BEDROCK_HAIKU_MODELID)

# initialize the retriever
retriever = ChromaQueryTextRetriever(document_store)

# Haystack uses jinja template formatting
template = """
<result>
{% for document in documents %}
    {{ document.content }}
{% endfor %}

To answer the question "{{question}}":
[Provide a concise answer to the question based on the given context. Include relevant details and figures as needed, but avoid unnecessary elaboration or tangents.]
</result>
"""

# Build the prompt and add other components to the RAG
# pipeline
prompt_builder = PromptBuilder(template=template)
rag_pipeline = Pipeline()
rag_pipeline.add_component("retriever", retriever)
rag_pipeline.add_component("prompt_builder", prompt_builder)
rag_pipeline.add_component("llm", generator)

rag_pipeline.connect("retriever", "prompt_builder.documents")
rag_pipeline.connect("prompt_builder", "llm")
# Out:
# [2024-11-16 13:10:52,863] p36636 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# <haystack.core.pipeline.pipeline.Pipeline object at 0x343d6e3d0>
# 🚅 Components
#   - retriever: ChromaQueryTextRetriever
#   - prompt_builder: PromptBuilder
#   - llm: AmazonBedrockGenerator
# 🛤️ Connections
#   - retriever.documents -> prompt_builder.documents (List[Document])
#   - prompt_builder.prompt -> llm.prompt (str)

# %%
# view the pipeline. At this point, you should be able to see the pipeline
# graph, which shows the steps in the pipeline and the dependencies between them.
rag_pipeline.show()

# %%
retriever = rag_pipeline.get_component("retriever")
document_store = retriever.document_store
doc_count = len(document_store.filter_documents())
print(f"Number of documents in store: {doc_count}")
# Out:
# Number of documents in store: 1000

# %% [markdown]
# ### Save the haystack pipeline
# ---
#
# Now, before running inferences, we will save the pipeline and upload it to s3 for later use. This haystack pipeline is saved as a `yml` file within s3, as given below:
#
# ![haystack_yml](/images/yml_example.png)

# %%
# Create temporary file and save pipeline
with tempfile.NamedTemporaryFile(mode='w', suffix='.yml', delete=False) as tmp_file:
    print(f"Saving pipeline to {tmp_file.name}")
    rag_pipeline.dump(tmp_file)
    print(f"Saved pipeline to {tmp_file.name}")
    tmp_file_path = tmp_file.name
# Out:
# Saving pipeline to /var/folders/jy/g9mb5j5n6c11fgdj788p5rww0000gr/T/tmptx_6hyi_.yml
# Saved pipeline to /var/folders/jy/g9mb5j5n6c11fgdj788p5rww0000gr/T/tmptx_6hyi_.yml

# %%
import shutil
from io import BytesIO

# Initialize S3 client
s3_client = boto3.client('s3')

# Upload pipeline to S3
with open(tmp_file_path, 'rb') as file:
    s3_client.upload_fileobj(
        file, 
        g.HAYSTACK_PIPELINE_BUCKET, 
        g.HAYSTACK_PIPELINE_KEY
    )
    print(f"Uploaded pipeline to {g.HAYSTACK_PIPELINE_BUCKET}/{g.HAYSTACK_PIPELINE_KEY}")
# Out:
# [2024-11-16 13:10:53,698] p36636 {credentials.py:1278} INFO - Found credentials in shared credentials file: ~/.aws/credentials
# Uploaded pipeline to sagemaker-us-east-2-015469603702/pipelines/basic_rag_pipeline.yml

# %%
import shutil

# Create a zip file of the chroma store directory
chroma_zip_path = os.path.join(g.DATA_DIR, 'chroma_store.zip')
os.makedirs(os.path.dirname(chroma_zip_path), exist_ok=True)
shutil.make_archive(
    os.path.join(g.DATA_DIR, 'chroma_store'),
    'zip',
    chroma_persist_path
)

# Upload the zipped chroma store to S3
with open(chroma_zip_path, 'rb') as file:
    s3_client.upload_fileobj(
        file, 
        g.HAYSTACK_PIPELINE_BUCKET, 
        g.CHROMA_DOC_STORE_KEY
    )
    print(f"Uploaded document store to {g.HAYSTACK_PIPELINE_BUCKET}/{g.CHROMA_DOC_STORE_KEY}")

# Clean up the zip file
os.remove(chroma_zip_path)
# Out:
# Uploaded document store to sagemaker-us-east-2-015469603702/pipelines/document_store/chroma_store.zip

# %%
os.remove(tmp_file_path)
print(f"Removed the tmp file path containing the pipeline.")
# Out:
# Removed the tmp file path containing the pipeline.

# %% [markdown]
# Now that we have uploaded the haystack pipeline to s3, you can use it in a lambda function for example to serve it as an endpoint. For this you would have to create a lambda function, and in the lambda code:
#
# 1. Load the pipeline from the s3 location, use it for incoming requests.
#
# 1. Create an API gateway that triggers the function and passes in the user input that goes into the RAG pipeline.
